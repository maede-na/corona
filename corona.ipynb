# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\DELL 5110\WHO-COVID-19-global-data.csv', on_bad_lines='skip')
df
# Out:
#       Date_reported;Country_code;Country;WHO_region;New_cases;Cumulative_cases;New_deaths;Cumulative_deaths
# 0                   05/01/2020;AF;Afghanistan;EMRO;;0;;0
# 1                   12/01/2020;AF;Afghanistan;EMRO;;0;;0
# 2                   19/01/2020;AF;Afghanistan;EMRO;;0;;0
# 3                   26/01/2020;AF;Afghanistan;EMRO;;0;;0
# 4                   02/02/2020;AF;Afghanistan;EMRO;;0;;0
# ...                                                  ...
# 57353          14/07/2024;ZW;Zimbabwe;AFRO;;266385;;5740
# 57354         21/07/2024;ZW;Zimbabwe;AFRO;1;266386;;5740
# 57355          28/07/2024;ZW;Zimbabwe;AFRO;;266386;;5740
# 57356          04/08/2024;ZW;Zimbabwe;AFRO;;266386;;5740
# 57357          11/08/2024;ZW;Zimbabwe;AFRO;;266386;;5740
#
# [57358 rows x 1 columns]

# %%
print(df.isna().sum())
# Out:
# Date_reported;Country_code;Country;WHO_region;New_cases;Cumulative_cases;New_deaths;Cumulative_deaths    0
# dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
df = pd.read_csv(r'C:\Users\DELL 5110\WHO-COVID-19-global-data.csv', sep=';')

# Strip whitespace from column names
df.columns = df.columns.str.strip()

# Convert the 'Date_reported' column to datetime format
df['Date_reported'] = pd.to_datetime(df['Date_reported'], format='%d/%m/%Y')

# Group by WHO region and sum the new cases and deaths
region_summary = df.groupby('WHO_region').agg({
    'New_cases': 'sum',
    'New_deaths': 'sum'
}).reset_index()

# Sort the regions by total new cases
region_summary = region_summary.sort_values(by='New_cases', ascending=False)

# Plotting
plt.figure(figsize=(12, 6))

# Bar chart for new cases by WHO region
plt.bar(region_summary['WHO_region'], region_summary['New_cases'], color='skyblue', label='New Cases')
plt.bar(region_summary['WHO_region'], region_summary['New_deaths'], color='salmon', label='New Deaths', alpha=0.7)

# Adding titles and labels
plt.title('Total New COVID-19 Cases and Deaths by WHO Region')
plt.xlabel('WHO Region')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend()
plt.grid(axis='y')

# Show the plot
plt.tight_layout()
plt.show()

# %%
print(df.columns)
# Out:
# Index(['Date_reported;Country_code;Country;WHO_region;New_cases;Cumulative_cases;New_deaths;Cumulative_deaths'], dtype='object')
